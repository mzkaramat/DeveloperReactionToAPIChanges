# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
from IPython import display
import math
from pprint import pprint
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
import re
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
sns.set(style='darkgrid', context='talk', palette='Dark2')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mk73680\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mk73680\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mk73680\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('dataset.csv')
print(df.head())
print(df.shape)
# Out:
#    antwort_id                                              Title  \
# 0     8273117                                                NaN
# 1    33446954  Angular JSON Display Single Result without Ng-...
# 2    25183554                                                NaN
# 3    25194037                                                NaN
# 4    16695595                        Twitter iOS 6 oauth or not?
#
#                                                 Body  Score  \
# 0  <p>You would have to custom code the second pa...      1
# 1  <p>I'm still develop app for show news update ...      0
# 2  <p>To get the user's information from Twitter,...      2
# 3  <p>The Play JSON framework has <a href="http:/...      4
# 4  <p>Am i correct in saying that you do not need...      0
#
#           CreationDate    parentid  Post Link
# 0  2011-11-25 18:42:22   8268229.0    8273117
# 1  2015-10-31 01:01:22         NaN   33446954
# 2  2014-08-07 13:14:55  25178919.0   25183554
# 3  2014-08-07 23:47:45  25193016.0   25194037
# 4  2013-05-22 15:18:24         NaN   16695595
# (15890, 7)

# %%
stop_words = stopwords.words('english')
print('version' in stop_words)
print('v' in stop_words)
print('ver' in stop_words)

r = re.compile(".*ver.*")
newlist = filter(r.match, stop_words)
print(list(newlist))

tokenizer = RegexpTokenizer(r'\w+')
    
def process_text(headlines):
    tokens = []
    for line in headlines:
        toks = tokenizer.tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        tokens.extend(toks)
    
    return tokens

temp_list = process_text(df.loc[:,'Body'])
# Out:
# False
# False
# False
# ['over', 'very']

# %%
df.head()
# Out:
#    antwort_id                                              Title  \
# 0     8273117                                                NaN
# 1    33446954  Angular JSON Display Single Result without Ng-...
# 2    25183554                                                NaN
# 3    25194037                                                NaN
# 4    16695595                        Twitter iOS 6 oauth or not?
#
#                                                 Body  Score  \
# 0  <p>You would have to custom code the second pa...      1
# 1  <p>I'm still develop app for show news update ...      0
# 2  <p>To get the user's information from Twitter,...      2
# 3  <p>The Play JSON framework has <a href="http:/...      4
# 4  <p>Am i correct in saying that you do not need...      0
#
#           CreationDate    parentid  Post Link
# 0  2011-11-25 18:42:22   8268229.0    8273117
# 1  2015-10-31 01:01:22         NaN   33446954
# 2  2014-08-07 13:14:55  25178919.0   25183554
# 3  2014-08-07 23:47:45  25193016.0   25194037
# 4  2013-05-22 15:18:24         NaN   16695595

# %%
np.mean(df.Body.str.contains('.*api.*'))

# %%
df.columns
print(df.shape)
len(temp_list)
# Out:
# (15890, 7)
# 5386054

# %%
for i in range(10):
    print(temp_list[i])

from collections import Counter
count_word_dict = Counter(temp_list)
# Out:
# p
# would
# custom
# code
# second
# part
# p
# ol
# li
# p

# %%
temp_list.count('api')
# Out:
# 38378

# %%
type(count_word_dict)
# Out:
# collections.Counter

# %%
sia = SIA()
results = []

for index, row in df.iterrows():
    pol_score = sia.polarity_scores(df.iloc[index,2])
    pol_score['headline'] = df.iloc[index,2]
    results.append(pol_score)
    
pprint(results[:3], width=100)
# Out:
# [{'compound': 0.0,
#   'headline': '<p>You would have to custom code the second part.</p>\n'
#               '\n'
#               '<ol>\n'
#               '<li><p>Use <a href="https://dev.twitter.com/docs/api/1/get/statuses/user_timeline" '
#               'rel="nofollow">https://dev.twitter.com/docs/api/1/get/statuses/user_timeline</a> - '
#               'to get the latest tweets from a specific user.</p></li>\n'
#               '<li><p>Write Code to search within the response Object of (1) with the hashtag '
#               '(search-key).</p></li>\n'
#               '</ol>\n',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.3736,
#   'headline': "<p>I'm still develop app for show news update from API Json. Now, I load all of "
#               'data from json. Then filter it with ng-repeat. This is the problem because when '
#               "load data, it's so slow. So many data.</p>\n"
#               '\n'
#               '<p>I want to make that in controller, only 1 row selected. So, it can be easyly '
#               'load to the detail page.</p>\n'
#               '\n'
#               "<p>I also want to order the news by desc. I've use | orderby. It works. But i must "
#               'load all of data in one time. It make my apps slow. I want to make swipe to refresh '
#               'that only show 8 posts at the first time. But, will load the data when swipe (like '
#               'twitter).</p>\n'
#               '\n'
#               '<p>Controller.php</p>\n'
#               '\n'
#               "<pre><code>.controller('MediaCtrl', function($scope, $http) {\n"
#               '\n'
#               '  '
#               "$http.get('http://api.pemiluapi.org/rekam-jejak-media/api/rekam_jejak?apiKey=c6a0237499f3e4197546b5551a3a864f')\n"
#               '       .then(function(res){\n'
#               '          $scope.medias = res.data;  \n'
#               '          //alert(res.data);              \n'
#               '        });\n'
#               '\n'
#               '\n'
#               '})\n'
#               '\n'
#               ".controller('MediaDetailCtrl', function($scope, $stateParams, $http) {\n"
#               '\n'
#               '  '
#               "$http.get('http://api.pemiluapi.org/rekam-jejak-media/api/rekam_jejak?apiKey=c6a0237499f3e4197546b5551a3a864f')\n"
#               '       .then(function(res){\n'
#               '          $scope.medias = res.data;  \n'
#               '          $scope.mediaid = $stateParams.mediaId;\n'
#               '          //alert(res.data);              \n'
#               '        });\n'
#               '\n'
#               '\n'
#               '})\n'
#               '</code></pre>\n'
#               '\n'
#               '<p>Detail.html</p>\n'
#               '\n'
#               '<pre><code>   &lt;ion-content style="padding:30px;" class="item-remove-animate " '
#               'ng-repeat="media in medias.data.results.rekam_jejak | filter: {id: mediaid}" '
#               'type="item-text-wrap" href="#/tab/daerah/{{province.id}}"&gt;\n'
#               '</code></pre>\n'
#               '\n'
#               '<p>Media.html (all news)</p>\n'
#               '\n'
#               '<pre><code> &lt;ion-item class="item-remove-animate " ng-repeat="media in '
#               'medias.data.results.rekam_jejak | orderBy:\'id\':true" type="item-text-wrap" '
#               'href="#/tab/media-detail/{{media.id}}"&gt;\n'
#               '</code></pre>\n'
#               '\n'
#               '<p>Thanks in advance :) let share</p>\n',
#   'neg': 0.016,
#   'neu': 0.942,
#   'pos': 0.042},
#  {'compound': 0.9408,
#   'headline': "<p>To get the user's information from Twitter, you can use "
#               "<strong>OAuth.io</strong>'s iOS SDK:\n"
#               '<a href="https://github.com/oauth-io/oauth-ios" '
#               'rel="nofollow">https://github.com/oauth-io/oauth-ios</a></p>\n'
#               '\n'
#               '<p>After having created an account on <a href="https://oauth.io" '
#               'rel="nofollow">https://oauth.io</a>, and added Twitter as a provider, you\'ll be '
#               "able to get the user's info quite easily. You just need to follow these steps:</p>\n"
#               '\n'
#               '<h3><strong>1</strong> Install the framework through Cocoa Pods, or manually</h3>\n'
#               '\n'
#               '<p>Via Cocoa pod:</p>\n'
#               '\n'
#               '<pre><code>$ pod install "OAuth.io"\n'
#               '</code></pre>\n'
#               '\n'
#               '<p>Manually:</p>\n'
#               '\n'
#               '<p>Just get the <code>OAuthiOS.framework</code> file <a '
#               'href="https://github.com/oauth-io/oauth-ios/tree/master/Dist" '
#               'rel="nofollow">here</a> and install it like any other framework.</p>\n'
#               '\n'
#               '<h3><strong>2</strong> Insert the header reference</h3>\n'
#               '\n'
#               '<p>Add <code>#import &lt;OAuthiOS/OAuthiOS.h&gt;</code> in your '
#               'ViewController.</p>\n'
#               '\n'
#               '<h3><strong>3</strong> Set the view controller as delegate to '
#               'OAuthIODelegate:</h3>\n'
#               '\n'
#               '<pre><code>@interface MyViewController : UIViewController&lt;OAuthIODelegate&gt;\n'
#               '//[...]\n'
#               '@end\n'
#               '</code></pre>\n'
#               '\n'
#               '<h3><strong>4</strong> Initialize and launch an authentication popup in the '
#               'ViewController:</h3>\n'
#               '\n'
#               '<pre><code>OAuthIOModal *oauthioModal = [[OAuthIOModal alloc] '
#               'initWithKey:@"your_app_public_key" delegate:self];\n'
#               '[oauthioModal showWithProvider:@"twitter"];\n'
#               '</code></pre>\n'
#               '\n'
#               '<h3><strong>5</strong> Implement the following delegate method to get a Request '
#               "Object, that lets you retrieve the user's information, thanks to the "
#               '<code>me</code> method:</h3>\n'
#               '\n'
#               '<pre><code>- (void)didReceiveOAuthIOResponse:(OAuthIORequest *)request\n'
#               '{\n'
#               '    [_request me:nil success:^(NSDictionary *output, NSString *body, '
#               'NSHTTPURLResponse \n'
#               '    *httpResponse)\n'
#               '     {\n'
#               '         NSLog(@"name: %@", [output objectForKey:@"name"]);\n'
#               '     }];\n'
#               '}\n'
#               '</code></pre>\n'
#               '\n'
#               '<p>To get more information about the iOS SDK, feel free to check out the guide '
#               'here:</p>\n'
#               '\n'
#               '<p><a href="https://oauth.io/getting-started?ios&amp;None" '
#               'rel="nofollow">https://oauth.io/getting-started?ios&amp;None</a></p>\n'
#               '\n'
#               '<p>You can also follow a git based tutorial here:</p>\n'
#               '\n'
#               '<p><a href="https://oauth.io/docs/tutorials/client/ios" '
#               'rel="nofollow">https://oauth.io/docs/tutorials/client/ios</a></p>\n'
#               '\n'
#               '<p>And find the reference documentation of the SDK here:</p>\n'
#               '\n'
#               '<p><a href="https://oauth.io/docs/api-reference/client/ios" '
#               'rel="nofollow">https://oauth.io/docs/api-reference/client/ios</a></p>\n'
#               '\n'
#               '<p>Note that OAuth.io also open sourced their core in the oauthd project (check out '
#               'the repo here: <a href="https://github.com/oauth-io/oauthd" '
#               'rel="nofollow">https://github.com/oauth-io/oauthd</a>)</p>\n'
#               '\n'
#               '<p>Hope this helps :)</p>\n',
#   'neg': 0.0,
#   'neu': 0.93,
#   'pos': 0.07}]

# %%
df = pd.DataFrame.from_records(results)
df.head()
# Out:
#    compound                                           headline    neg    neu  \
# 0    0.0000  <p>You would have to custom code the second pa...  0.000  1.000
# 1    0.3736  <p>I'm still develop app for show news update ...  0.016  0.942
# 2    0.9408  <p>To get the user's information from Twitter,...  0.000  0.930
# 3    0.4830  <p>The Play JSON framework has <a href="http:/...  0.022  0.919
# 4    0.6705  <p>Am i correct in saying that you do not need...  0.000  0.889
#
#      pos
# 0  0.000
# 1  0.042
# 2  0.070
# 3  0.059
# 4  0.111

# %%
#Using threshold of -0.2 and 0.2 for labelling data either as positive or negative
df['label'] = 0
df.loc[df['compound'] > 0.2, 'label'] = 1
df.loc[df['compound'] < -0.2, 'label'] = -1
df.head()

print("Positive headlines:\n")
pprint(list(df[df['label'] == 1].headline)[:5], width=200)

print("\nNegative headlines:\n")
pprint(list(df[df['label'] == -1].headline)[:5], width=200)

print(df.label.value_counts())
print(df.label.value_counts(normalize=True) * 100)
# Out:
# Positive headlines:
#
# ["<p>I'm still develop app for show news update from API Json. Now, I load all of data from json. Then filter it with ng-repeat. This is the problem because when load data, it's so slow. So many "
#  'data.</p>\n'
#  '\n'
#  '<p>I want to make that in controller, only 1 row selected. So, it can be easyly load to the detail page.</p>\n'
#  '\n'
#  "<p>I also want to order the news by desc. I've use | orderby. It works. But i must load all of data in one time. It make my apps slow. I want to make swipe to refresh that only show 8 posts at the "
#  'first time. But, will load the data when swipe (like twitter).</p>\n'
#  '\n'
#  '<p>Controller.php</p>\n'
#  '\n'
#  "<pre><code>.controller('MediaCtrl', function($scope, $http) {\n"
#  '\n'
#  "  $http.get('http://api.pemiluapi.org/rekam-jejak-media/api/rekam_jejak?apiKey=c6a0237499f3e4197546b5551a3a864f')\n"
#  '       .then(function(res){\n'
#  '          $scope.medias = res.data;  \n'
#  '          //alert(res.data);              \n'
#  '        });\n'
#  '\n'
#  '\n'
#  '})\n'
#  '\n'
#  ".controller('MediaDetailCtrl', function($scope, $stateParams, $http) {\n"
#  '\n'
#  "  $http.get('http://api.pemiluapi.org/rekam-jejak-media/api/rekam_jejak?apiKey=c6a0237499f3e4197546b5551a3a864f')\n"
#  '       .then(function(res){\n'
#  '          $scope.medias = res.data;  \n'
#  '          $scope.mediaid = $stateParams.mediaId;\n'
#  '          //alert(res.data);              \n'
#  '        });\n'
#  '\n'
#  '\n'
#  '})\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>Detail.html</p>\n'
#  '\n'
#  '<pre><code>   &lt;ion-content style="padding:30px;" class="item-remove-animate " ng-repeat="media in medias.data.results.rekam_jejak | filter: {id: mediaid}" type="item-text-wrap" '
#  'href="#/tab/daerah/{{province.id}}"&gt;\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>Media.html (all news)</p>\n'
#  '\n'
#  '<pre><code> &lt;ion-item class="item-remove-animate " ng-repeat="media in medias.data.results.rekam_jejak | orderBy:\'id\':true" type="item-text-wrap" href="#/tab/media-detail/{{media.id}}"&gt;\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>Thanks in advance :) let share</p>\n',
#  "<p>To get the user's information from Twitter, you can use <strong>OAuth.io</strong>'s iOS SDK:\n"
#  '<a href="https://github.com/oauth-io/oauth-ios" rel="nofollow">https://github.com/oauth-io/oauth-ios</a></p>\n'
#  '\n'
#  '<p>After having created an account on <a href="https://oauth.io" rel="nofollow">https://oauth.io</a>, and added Twitter as a provider, you\'ll be able to get the user\'s info quite easily. You '
#  'just need to follow these steps:</p>\n'
#  '\n'
#  '<h3><strong>1</strong> Install the framework through Cocoa Pods, or manually</h3>\n'
#  '\n'
#  '<p>Via Cocoa pod:</p>\n'
#  '\n'
#  '<pre><code>$ pod install "OAuth.io"\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>Manually:</p>\n'
#  '\n'
#  '<p>Just get the <code>OAuthiOS.framework</code> file <a href="https://github.com/oauth-io/oauth-ios/tree/master/Dist" rel="nofollow">here</a> and install it like any other framework.</p>\n'
#  '\n'
#  '<h3><strong>2</strong> Insert the header reference</h3>\n'
#  '\n'
#  '<p>Add <code>#import &lt;OAuthiOS/OAuthiOS.h&gt;</code> in your ViewController.</p>\n'
#  '\n'
#  '<h3><strong>3</strong> Set the view controller as delegate to OAuthIODelegate:</h3>\n'
#  '\n'
#  '<pre><code>@interface MyViewController : UIViewController&lt;OAuthIODelegate&gt;\n'
#  '//[...]\n'
#  '@end\n'
#  '</code></pre>\n'
#  '\n'
#  '<h3><strong>4</strong> Initialize and launch an authentication popup in the ViewController:</h3>\n'
#  '\n'
#  '<pre><code>OAuthIOModal *oauthioModal = [[OAuthIOModal alloc] initWithKey:@"your_app_public_key" delegate:self];\n'
#  '[oauthioModal showWithProvider:@"twitter"];\n'
#  '</code></pre>\n'
#  '\n'
#  "<h3><strong>5</strong> Implement the following delegate method to get a Request Object, that lets you retrieve the user's information, thanks to the <code>me</code> method:</h3>\n"
#  '\n'
#  '<pre><code>- (void)didReceiveOAuthIOResponse:(OAuthIORequest *)request\n'
#  '{\n'
#  '    [_request me:nil success:^(NSDictionary *output, NSString *body, NSHTTPURLResponse \n'
#  '    *httpResponse)\n'
#  '     {\n'
#  '         NSLog(@"name: %@", [output objectForKey:@"name"]);\n'
#  '     }];\n'
#  '}\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>To get more information about the iOS SDK, feel free to check out the guide here:</p>\n'
#  '\n'
#  '<p><a href="https://oauth.io/getting-started?ios&amp;None" rel="nofollow">https://oauth.io/getting-started?ios&amp;None</a></p>\n'
#  '\n'
#  '<p>You can also follow a git based tutorial here:</p>\n'
#  '\n'
#  '<p><a href="https://oauth.io/docs/tutorials/client/ios" rel="nofollow">https://oauth.io/docs/tutorials/client/ios</a></p>\n'
#  '\n'
#  '<p>And find the reference documentation of the SDK here:</p>\n'
#  '\n'
#  '<p><a href="https://oauth.io/docs/api-reference/client/ios" rel="nofollow">https://oauth.io/docs/api-reference/client/ios</a></p>\n'
#  '\n'
#  '<p>Note that OAuth.io also open sourced their core in the oauthd project (check out the repo here: <a href="https://github.com/oauth-io/oauthd" '
#  'rel="nofollow">https://github.com/oauth-io/oauthd</a>)</p>\n'
#  '\n'
#  '<p>Hope this helps :)</p>\n',
#  '<p>The Play JSON framework has <a href="http://www.playframework.com/documentation/2.3.x/api/scala/index.html#play.api.libs.json.Reads$" rel="nofollow">a number of built-in objects</a> for '
#  'handling JSON, among which is <code>Reads.traversableReads</code>, which will be used implicitly to deserialize collections of other types for which a <code>Reads</code> object can be found '
#  "implicitly. And you wrote a proper <code>Reads</code> object. So unless I'm missing something, you're good to go:</p>\n"
#  '\n'
#  '<pre><code>scala&gt; import play.api.libs.json._\n'
#  'import play.api.libs.json._\n'
#  '\n'
#  'scala&gt; import play.api.libs.functional.syntax._\n'
#  'import play.api.libs.functional.syntax._\n'
#  '\n'
#  'scala&gt; case class Group(id: String, name: String)\n'
#  'defined class Group\n'
#  '\n'
#  'scala&gt; implicit val twitterGroupReads: Reads[Group] = (\n'
#  '     |     (JsPath \\\\ "id_str").read[String] and\n'
#  '     |     (JsPath \\\\ "name").read[String]\n'
#  '     |     )(Group.apply _)\n'
#  'twitterGroupReads: play.api.libs.json.Reads[Group] = play.api.libs.json.Reads$$anon$8@f2fae02\n'
#  '\n'
#  'scala&gt; val json = Json.parse("""[{"id_str":"67979542","name":"account"}, {"id_str":"12345678","name":"account2"}, {"id_str":"3423423423","name":"account3"}]""")\n'
#  'json: play.api.libs.json.JsValue = [{"id_str":"67979542","name":"account"},{"id_str":"12345678","name":"account2"},{"id_str":"3423423423","name":"account3"}]\n'
#  '\n'
#  'scala&gt; json.as[Seq[Group]]\n'
#  'res0: Seq[Group] = List(Group(67979542,account), Group(12345678,account2), Group(3423423423,account3))\n'
#  '</code></pre>\n',
#  '<p>Am i correct in saying that you do not need too use oauth to use the twitter api if your using iOS 6 &amp; using the accounts method to login? I want too use most of the twitter 1.1 api and was '
#  'wondering best way to authenticate the user.</p>\n',
#  '<p>I am trying to follow the instructions on this site: <a href="http://sathomas.me/acc-wizard/" rel="nofollow">http://sathomas.me/acc-wizard/</a></p>\n'
#  '\n'
#  "<p>I have followed the instructions, and even copied and pasted the exact code. Can you tell me what's going wrong? I have verified that all the code is located in the proper directory. Here is an "
#  'image of what\'s displaying on my site: <a href="http://i.imgur.com/BSmrFZQ.png" rel="nofollow">http://i.imgur.com/BSmrFZQ.png</a></p>\n'
#  '\n'
#  "<p>Here's my code, the CSS is added in the header and is not in the code below: </p>\n"
#  '\n'
#  '<pre><code>&lt;div id="body"&gt;\n'
#  '        &lt;div class="row-fluid breadcrumbs margin-bottom-30"&gt;\n'
#  '            &lt;div class="container"&gt;\n'
#  '                &lt;h1 class="pull-left"&gt;Book Now!&lt;/h1&gt;\n'
#  '\n'
#  '            &lt;/div&gt;&lt;!--/container--&gt;\n'
#  '        &lt;/div&gt;&lt;!--/breadcrumbs--&gt;\n'
#  '\n'
#  '    &lt;div class="container"&gt;     \n'
#  '            &lt;div class="row-fluid"&gt;\n'
#  '                &lt;div class="span9"&gt;\n'
#  '\n'
#  '\n'
#  '        &lt;div class="row-fluid acc-wizard"&gt;\n'
#  '          &lt;div class="span3" style="padding-left: 2em;"&gt;\n'
#  '            &lt;p style="margin-bottom: 2em;"&gt;\n'
#  '              Follow the steps below to add an accordion wizard to your web page.\n'
#  '            &lt;/p&gt;\n'
#  '            &lt;ol class="acc-wizard-sidebar"&gt;\n'
#  '              &lt;li class="acc-wizard-todo"&gt;&lt;a href="#prerequisites"&gt;Prerequisites&lt;/a&gt;&lt;/li&gt;\n'
#  '              &lt;li class="acc-wizard-todo"&gt;&lt;a href="#addwizard"&gt;Add Wizard&lt;/a&gt;&lt;/li&gt;\n'
#  '              &lt;li class="acc-wizard-todo"&gt;&lt;a href="#adjusthtml"&gt;Adjust HTML&lt;/a&gt;&lt;/li&gt;\n'
#  '              &lt;li class="acc-wizard-todo"&gt;&lt;a href="#viewpage"&gt;Release&lt;/a&gt;&lt;/li&gt;\n'
#  '            &lt;/ol&gt;\n'
#  '          &lt;/div&gt;\n'
#  '          &lt;div class="span9"&gt;\n'
#  '            &lt;div class="accordion" id="accordion-demo"&gt;\n'
#  '              &lt;div class="accordion-group"&gt;\n'
#  '                &lt;div class="accordion-heading"&gt;\n'
#  '                  &lt;a class="accordion-toggle" data-toggle="collapse" data-parent="#accordion-demo" href="#prerequisites"&gt;\n'
#  '                    Install Bootstrap and jQuery\n'
#  '                  &lt;/a&gt;\n'
#  '                &lt;/div&gt;\n'
#  '                &lt;div id="prerequisites" class="accordion-body collapse in"&gt;\n'
#  '                  &lt;div class="accordion-inner"&gt;\n'
#  '                    &lt;form id="form-prerequisites"&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        The accordion wizard depends on two other open source packages:\n'
#  '                        &lt;ul&gt;\n'
#  '                          &lt;li&gt;The Bootstrap framework, available &lt;a href="http://twitter.github.com/bootstrap/index.html"&gt;here&lt;/a&gt;.\n'
#  '                          &lt;li&gt;The jQuery javascript library, available &lt;a href="http://jquery.com"&gt;here&lt;/a&gt;.\n'
#  '                        &lt;/ul&gt;\n'
#  '                        Note that Bootstrap itself depends on jQuery for its interactive\n'
#  "                        components, so if you're using Bootstrap you probably already have\n"
#  '                        jQuery as well.\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;p&gt;\n'
#  "                        You'll include the CSS styles for Bootstrap in the\n"
#  '                        &lt;code&gt;&amp;lt;head&amp;gt;&lt;/code&gt; of your HTML file, for example:\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;pre&gt;&lt;!--\n'
#  '                      --&gt;&amp;lt;link href="css/bootstrap.min.css" rel="stylesheet"&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;link href="css/bootstrap-responsive.min.css" rel="stylesheet"&amp;gt;&lt;!--\n'
#  '                      --&gt;&lt;/pre&gt;\n'
#  '                      &lt;p&gt;\n'
#  "                        and you'll include jQuery and Bootstrap javascript files at the\n"
#  '                        end of your &lt;code&gt;&amp;lt;body&amp;gt;&lt;/code&gt; section, for example:\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;pre&gt;&lt;!--\n'
#  '                      --&gt;&amp;lt;script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.0/jquery.min.js" type="text/javascript"&amp;gt;&amp;lt;/script&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;script src="js/bootstrap.min.js"&amp;gt;&amp;lt;/script&amp;gt;&lt;!--\n'
#  '                      --&gt;&lt;/pre&gt;\n'
#  '                    &lt;/form&gt;\n'
#  '                  &lt;/div&gt; &lt;!--/.accordion-inner --&gt;\n'
#  '                &lt;/div&gt; &lt;!-- /#prerequisites --&gt;\n'
#  '              &lt;/div&gt; &lt;!-- /.accordion-group --&gt;\n'
#  '\n'
#  '              &lt;div class="accordion-group"&gt;\n'
#  '                &lt;div class="accordion-heading"&gt;\n'
#  '                  &lt;a class="accordion-toggle" data-toggle="collapse" data-parent="#accordion-demo" href="#addwizard"&gt;\n'
#  '                    Add Accordion Wizard\n'
#  '                  &lt;/a&gt;\n'
#  '                &lt;/div&gt;\n'
#  '                &lt;div id="addwizard" class="accordion-body collapse in"&gt;\n'
#  '                  &lt;div class="accordion-inner"&gt;\n'
#  '                    &lt;form id="form-addwizard"&gt;\n'
#  '                      &lt;p&gt;\n'
#  "                        If you haven't already found it, the source code for the\n"
#  '                        accordion wizard is available on github\n'
#  '                        &lt;a href="https://github.com/sathomas/acc-wizard"&gt;here&lt;/a&gt;.\n'
#  '                        There are two main folders, &lt;code&gt;/src&lt;/code&gt; and\n'
#  '                        &lt;code&gt;/release&lt;/code&gt;.\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        There are two different ways to add the accordion wizard to\n'
#  '                        your pages. The simplest approach is just to add the CSS and\n'
#  '                        javascript files from the &lt;code&gt;/release&lt;/code&gt; folder\n'
#  '                        directly in your HTML without modifying them:\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;pre&gt;&lt;!--\n'
#  '                      --&gt;&amp;lt;link href="css/bootstrap.min.css" rel="stylesheet"&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;link href="css/bootstrap-responsive.min.css" rel="stylesheet"&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;link href="css/acc-wizard.min.css" rel="stylesheet"&amp;gt;&lt;!--\n'
#  '                      --&gt;&lt;/pre&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        and\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;pre&gt;&lt;!--\n'
#  '                      --&gt;&amp;lt;script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.0/jquery.min.js" type="text/javascript"&amp;gt;&amp;lt;/script&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;script src="js/bootstrap.min.js"&amp;gt;&amp;lt;/script&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;script src="js/acc-wizard.min.js"&amp;gt;&amp;lt;/script&amp;gt;&lt;!--\n'
#  '                      --&gt;&lt;/pre&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        The release styles for the accordion wizard are based on\n'
#  "                        Bootstrap's default styles. If you've tweaked the Bootstrap\n"
#  "                        styles (e.g. by changing the link color), you'll want to\n"
#  '                        make corresponding tweaks to &lt;code&gt;acc-wizard.min.css&lt;/code&gt;.\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;p&gt;\n'
#  "                        Alternatively, if you're building custom CSS and javascript,\n"
#  '                        then you might want to start with the files in the &lt;code&gt;/src&lt;/code&gt;\n'
#  '                        folder and adapt them to your source code. The &lt;code&gt;/src&lt;/code&gt;\n'
#  '                        folder contains a LESS file and uncompressed (and commented)\n'
#  '                        javascript. Note that the &lt;code&gt;acc-wizard.less&lt;/code&gt; file\n'
#  "                        depends on variables defined in Bootstrap's &lt;code&gt;variables.less&lt;/code&gt;\n"
#  '                        file.\n'
#  '                    &lt;/form&gt;\n'
#  '                  &lt;/div&gt; &lt;!--/.accordion-inner --&gt;\n'
#  '                &lt;/div&gt; &lt;!-- /#addwizard --&gt;\n'
#  '              &lt;/div&gt; &lt;!-- /.accordion-group --&gt;\n'
#  '\n'
#  '              &lt;div class="accordion-group"&gt;\n'
#  '                &lt;div class="accordion-heading"&gt;\n'
#  '                  &lt;a class="accordion-toggle" data-toggle="collapse" data-parent="#accordion-demo" href="#adjusthtml"&gt;\n'
#  '                    Adjust Your HTML Markup\n'
#  '                  &lt;/a&gt;\n'
#  '                &lt;/div&gt;\n'
#  '                &lt;div id="adjusthtml" class="accordion-body collapse in"&gt;\n'
#  '                  &lt;div class="accordion-inner"&gt;\n'
#  '                    &lt;form id="form-adjusthtml"&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        Now you can modify your HTML markup to activate the accordion\n'
#  '                        wizard. There are two parts to the markup&amp;mdash;the collapsible\n'
#  '                        accordion itself and the task list. I prefer putting both in\n'
#  '                        the same &lt;code&gt;.row&lt;/code&gt; with the task list taking up a\n'
#  '                        &lt;code&gt;.span3&lt;/code&gt; and the accordion panels in a &lt;code&gt;.span9&lt;/code&gt;,\n'
#  "                        but that's not a requirement.\n"
#  '                      &lt;/p&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        The accordion panel can be exactly as documented in the\n'
#  '                        &lt;a href="http://twitter.github.com/bootstrap/javascript.html#collapse"&gt;Bootstrap example&lt;/a&gt;,\n'
#  "                        but I think there's a problem with the Bootstrap implementation.\n"
#  '                        Specifically, the Bootstrap example only adds the class\n'
#  '                        &lt;code&gt;.in&lt;/code&gt; to one of the accordion panels. That class\n'
#  '                        marks the panel as visible by default. The problem with only\n'
#  '                        having one panel visible by default is that users without\n'
#  '                        javascript will &lt;strong&gt;never&lt;/strong&gt; be able to see the other\n'
#  "                        panels. Sure, that's a minority of users, but why make your\n"
#  '                        pages unworkable even for a small minority. Instead, I suggest\n'
#  '                        adding &lt;code&gt;.in&lt;/code&gt; to all your &lt;code&gt;.collapse&lt;/code&gt;\n'
#  '                        elements and have javascript code select only one to make\n'
#  '                        visible when it runs. The accordion wizard javascript will handle\n'
#  '                        that for you if you choose to use that approach.\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        The sidebar task list is nothing but a standard HTML ordered\n'
#  '                        list. The only required additions are adding the\n'
#  '                        &lt;code&gt;.acc-wizard-sidebar&lt;/code&gt; class to the &lt;code&gt;&amp;lt;ol&amp;gt;&lt;/code&gt;\n'
#  '                        element and &lt;code&gt;.acc-wizard-todo&lt;/code&gt; to the individual list\n'
#  '                        items. If you want to indicate that some steps are already\n'
#  '                        complete, you can instead add the &lt;code&gt;.acc-wizard-completed&lt;/code&gt;\n'
#  '                        class to the corresponding &lt;code&gt;&amp;lt;li&amp;gt;&lt;/code&gt; elements.\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;pre&gt;&lt;!--\n'
#  '                      --&gt;&amp;lt;ol class="acc-wizard-sidebar"&amp;gt;\n'
#  '    &lt;!--              --&gt;  &amp;lt;li class="acc-wizard-todo"&amp;gt;&amp;lt;a href="#prerequisites"&gt;Install Bootstrap and jQuery&amp;lt;/a&amp;gt;&amp;lt;/li&amp;gt;\n'
#  '    &lt;!--              --&gt;  &amp;lt;li class="acc-wizard-todo"&amp;gt;&amp;lt;a href="#addwizard"&gt;Add Accordion Wizard&amp;lt;/a&amp;gt;&amp;lt;/li&amp;gt;\n'
#  '    &lt;!--              --&gt;  &amp;lt;li class="acc-wizard-todo"&amp;gt;&amp;lt;a href="#adjusthtml"&gt;Adjust Your HTML Markup&amp;lt;/a&amp;gt;&amp;lt;/li&amp;gt;\n'
#  '    &lt;!--              --&gt;  &amp;lt;li class="acc-wizard-todo"&amp;gt;&amp;lt;a href="#viewpage"&gt;Test Your Page&amp;lt;/a&amp;gt;&amp;lt;/li&amp;gt;\n'
#  '    &lt;!--              --&gt;&amp;lt;/ol&gt;&lt;!--\n'
#  '                      --&gt;&lt;/pre&gt;\n'
#  '                      &lt;p&gt;\n'
#  "                        Finally, you'll want to active the wizard in your javascript.\n"
#  "                        That's nothing more than simply calling the plugin on an\n"
#  '                        appropriate selection.\n'
#  '                      &lt;/p&gt;\n'
#  '                      &lt;pre&gt;&lt;!--\n'
#  '                      --&gt;&amp;lt;script&amp;gt;\n'
#  '    &lt;!--              --&gt;    $(window).load(function() {\n'
#  '    &lt;!--              --&gt;        $(".acc-wizard").accwizard();\n'
#  '    &lt;!--              --&gt;    });\n'
#  '    &lt;!--              --&gt;&amp;lt;/script&amp;gt;&lt;!--\n'
#  '                     --&gt;&lt;/pre&gt;\n'
#  '                      &lt;p&gt;\n'
#  '                        The default options are probably fine for most uses, but\n'
#  '                        there are many customizations you can use when you activate\n'
#  '                        the wizard. Check out the documentation on\n'
#  '                        &lt;a href="https://github.com/sathomas/acc-wizard"&gt;github&lt;/a&gt;\n'
#  '                        for the details.\n'
#  '                      &lt;/p&gt;\n'
#  '                    &lt;/form&gt;\n'
#  '                  &lt;/div&gt; &lt;!--/.accordion-inner --&gt;\n'
#  '                &lt;/div&gt; &lt;!-- /#adjusthtml --&gt;\n'
#  '              &lt;/div&gt; &lt;!-- /.accordion-group --&gt;\n'
#  '\n'
#  '              &lt;div class="accordion-group"&gt;\n'
#  '                &lt;div class="accordion-heading"&gt;\n'
#  '                  &lt;a class="accordion-toggle" data-toggle="collapse" data-parent="#accordion-demo" href="#viewpage"&gt;\n'
#  '                    Test Your Page\n'
#  '                  &lt;/a&gt;\n'
#  '                &lt;/div&gt;\n'
#  '                &lt;div id="viewpage" class="accordion-body collapse in"&gt;\n'
#  '                  &lt;div class="accordion-inner"&gt;\n'
#  '                    &lt;form id="viewpage"&gt;\n'
#  '                      &lt;p&gt;\n'
#  "                        Naturally, the last thing you'll want to do is test your\n"
#  "                        page with the accordion wizard. Once you've confirmed that\n"
#  "                        it's working as expected, release it on the world. Your\n"
#  '                        users will definitely appreciate the feedback and guidance\n'
#  '                        it gives to multi-step and complex tasks on your web site.\n'
#  '                      &lt;/p&gt;\n'
#  '                    &lt;/form&gt;\n'
#  '                  &lt;/div&gt; &lt;!--/.accordion-inner --&gt;\n'
#  '                &lt;/div&gt; &lt;!-- /#viewpage --&gt;\n'
#  '              &lt;/div&gt; &lt;!-- /.accordion-group --&gt;\n'
#  '\n'
#  '            &lt;/div&gt;\n'
#  '          &lt;/div&gt;\n'
#  '        &lt;/div&gt;\n'
#  '\n'
#  '                &lt;/div&gt;\n'
#  '            &lt;/div&gt;\n'
#  '    &lt;/div&gt;\n'
#  '    &lt;script type="text/javascript" src="assets/js/acc-wizard.min.js"&gt;&lt;/script&gt;\n'
#  '    &lt;script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.0/jquery.min.js" type="text/javascript"&gt;&lt;/script&gt;\n'
#  '&lt;script src="assets/js/bootstrap.min.js"&gt;&lt;/script&gt;\n'
#  '    &lt;script&gt;\n'
#  '          function onNext(parent, panel) {\n'
#  '            hash = "#" + panel.id;\n'
#  '            $(".acc-wizard-sidebar",$(parent))\n'
#  '                .children("li")\n'
#  '                .children("a[href=\'" + hash + "\']")\n'
#  '                .parent("li")\n'
#  '                .removeClass("acc-wizard-todo")\n'
#  '                .addClass("acc-wizard-completed");\n'
#  '          }\n'
#  '          $(window).load(function() {\n'
#  '            $(".acc-wizard").accwizard({onNext: onNext});\n'
#  '          })\n'
#  '        &lt;/script&gt;\n'
#  '</code></pre>\n']
#
# Negative headlines:
#
# ['<p>First, pass an argument "cursor=-1". You then get the first 20. The Twitter API will return a field called "next_cursor" - pass this to the cursor and you get the next 20.</p>\n'
#  '\n'
#  '<p>Example (pseudocode):</p>\n'
#  '\n'
#  '<pre><code>cursor = -1\n'
#  'do {\n'
#  '    # get data, using the cursor\n'
#  '    data = {}\n'
#  '\n'
#  '    cursor = data.next_cursor\n'
#  "} while (len(data) &gt; 0) # Loop while we're still getting data back\n"
#  '</code></pre>\n'
#  '\n'
#  '<p>More info on <a href="https://dev.twitter.com/docs/api/1/get/lists/members">https://dev.twitter.com/docs/api/1/get/lists/members</a></p>\n',
#  "<p>im using php and the twitter api library- when i send my message through the following code my links get messed up- as far as I know I'm using the standard twitter php api?</p>\n"
#  '\n'
#  "<pre><code>$result = $this-&gt;tweet-&gt;call('post', 'statuses/update', array('status' =&gt; $title));\n"
#  '</code></pre>\n'
#  '\n'
#  '<p>before i post </p>\n'
#  '\n'
#  '<pre><code>testing link tracking http://bit.ly/tvHaWN\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>after i post </p>\n'
#  '\n'
#  '<pre><code>testing link tracking http://t.co/ptdXXNDH&amp;lt;br&amp;gt;\n'
#  '</code></pre>\n'
#  '\n'
#  '<p>anyone else had a similar problem?</p>\n',
#  '<p>Twitter::SearchResults#next_results is private, because they try to provide uniform interface for enumeration. </p>\n'
#  '\n'
#  '<p>Look, there\'s included Twitter::Enumerable in <a href="https://github.com/sferik/twitter/blob/master/lib/twitter/search_results.rb" rel="nofollow">search_results.rb</a></p>\n'
#  '\n'
#  '<pre>\n'
#  'module Twitter\n'
#  '  class SearchResults\n'
#  '    include Twitter::Enumerable\n'
#  '\n'
#  '    ...\n'
#  '\n'
#  '    private\n'
#  '\n'
#  '    def last?\n'
#  '      !next_page?\n'
#  '    end\n'
#  '\n'
#  '    ...\n'
#  '\n'
#  '    def fetch_next_page\n'
#  '      response = @client.send(@request_method, @path, next_page).body\n'
#  '      self.attrs = response\n'
#  '    end\n'
#  '\n'
#  '    ...\n'
#  '\n'
#  '  end\n'
#  'end\n'
#  '\n'
#  '</pre>\n'
#  '\n'
#  '<p>And if you look at <a href="https://github.com/sferik/twitter/blob/master/lib/twitter/enumerable.rb" rel="nofollow">enumerable.rb</a>, you\'ll see that method\'s Twitter::SearchResults#last? '
#  'and Twitter::SearchResults#fetch_next_page are used by Twitter::SearchResults#each method</p>\n'
#  '\n'
#  '<pre>\n'
#  'module Twitter\n'
#  '  module Enumerable\n'
#  '    include ::Enumerable\n'
#  '\n'
#  '    # @return [Enumerator]\n'
#  '    def each(start = 0)\n'
#  '      return to_enum(:each, start) unless block_given?\n'
#  '      Array(@collection[start..-1]).each do |element|\n'
#  '        yield(element)\n'
#  '      end\n'
#  '      unless last?\n'
#  '        start = [@collection.size, start].max\n'
#  '        fetch_next_page\n'
#  '        each(start, &Proc.new)\n'
#  '      end\n'
#  '      self\n'
#  '    end\n'
#  '\n'
#  '    ...\n'
#  '\n'
#  '  end\n'
#  'end\n'
#  '</pre>\n'
#  '\n'
#  "<p>And Twitter::SearchResults#each will iterate over pages until there's @attrs[:search_metadata][:next_results] in Twitter's responses. So you need to break iteration after you'll reach 500th "
#  'element.</p>\n'
#  '\n'
#  '<p>I think you just need to use each</p>\n'
#  '\n'
#  '<pre><code>@data = []\n'
#  'tweet_number = 1\n'
#  'search_results = twt_client.search("hello world", count: 100, result_type: :recent)\n'
#  '\n'
#  'search_results.each do |tweet|\n'
#  '  @data &lt;&lt; tweet\n'
#  '  break if tweet_number == 500\n'
#  'end\n'
#  '</code></pre>\n'
#  '\n'
#  "<p>This post is a result of looking into gem's sources and twitter's api. I could make a mistake somewhere, since I haven't checked my thoughts in console. </p>\n",
#  '<p>when we use these apis </p>\n'
#  '\n'
#  '<p>•For Twitter: twitter4j\n'
#  '•For Facebook: fb-java-api\n'
#  '•For Linkedin: linkedin-j</p>\n'
#  '\n'
#  '<p>we will be redirected to the concern website, \n'
#  'but my question is in my own java application user needs to give the credentials only once \n'
#  'and having them i try to fetch information from these social websites to avoid user \n'
#  'using all social websites to get connect</p>\n',
#  "<p>I'm only new and learning so thanks for any advice you can give :) I'm making a really simple tool to retrieve specific data from a Twitter API 1.1 GET request for a school project. I'm using "
#  'J7mbo\'s <a href="https://github.com/J7mbo/twitter-api-php" rel="nofollow">TwitterAPIExchange.php</a> and format. I created an HTML form to pass data to the array and can POST requests to the API '
#  'without a problem. I can also successfully print specific data from a GET request to the API when I enter the variables into the $getfield in the PHP, but when I try and use a form to send  data '
#  'for GET requests I get the following errors:</p>\n'
#  '\n'
#  '<p>Notice: Undefined offset: 1 in /var/www/exp/TwitterAPIExchange.php on line 158</p>\n'
#  '\n'
#  '<p>Warning: Invalid argument supplied for foreach() in /var/www/exp/screen1.php on line 31</p>\n'
#  '\n'
#  '<p>Here is the code:</p>\n'
#  '\n'
#  "<pre><code>    ini_set('display_errors', 1); \n"
#  "    if(!empty($_GET ['screen_name'])) {\n"
#  "    require_once('TwitterAPIExchange.php');\n"
#  '\n'
#  '\n'
#  '    $settings = array(\n'
#  '    \'oauth_access_token\' =&gt; "MY_KEY_HERE",\n'
#  '    \'oauth_access_token_secret\' =&gt; "MY_KEY_HERE",\n'
#  '    \'consumer_key\' =&gt; "MY_KEY_HERE",\n'
#  '    \'consumer_secret\' =&gt; "MY_KEY_HERE",\n'
#  '    );\n'
#  '\n'
#  '    /** URL for REST request, see: https://dev.twitter.com/docs/api/1.1/ **/\n'
#  "    $url = 'https://api.twitter.com/1.1/friends/list.json';\n"
#  "    $getfield = $_GET['screen_name'];\n"
#  "    $requestMethod = 'GET';\n"
#  '\n'
#  '    /** Note: Set the GET field BEFORE calling buildOauth(); **/\n'
#  '    $twitter = new TwitterAPIExchange($settings);\n'
#  '    $response = $twitter-&gt;setGetfield($getfield)\n'
#  '                -&gt;buildOauth($url, $requestMethod)\n'
#  '                -&gt;performRequest();\n'
#  '\n'
#  '    ##This prints out the fields I am interested in##\n'
#  '\n'
#  '    $arrResults = json_decode($response,true);\n'
#  '\n'
#  "    foreach ($arrResults['users'] as $arrSearchResult) {\n"
#  "$strTweet = $arrSearchResult['created_at'] ;\n"
#  "$strTweet1 = $arrSearchResult['screen_name'] ;\n"
#  '    print_r("&lt;div class=\'tweet\'&gt;$strTweet $strTweet1&lt;/div&gt;");\n'
#  '}       \n'
#  '    }\n'
#  '\n'
#  '    ?&gt;\n'
#  '    &lt;h3&gt;Enter the name here&lt;/h3&gt;\n'
#  '    &lt;form action="" method="GET"&gt;\n'
#  '    &lt;input type="text" name="screen_name" /&gt;&lt;br /&gt;\n'
#  '    &lt;input type="submit" /&gt;\n'
#  '    &lt;/form&gt;\n'
#  '</code></pre>\n'
#  '\n'
#  "<p>So, I'm thinking that the request is being malformed before OAuth, because I get the same errors even when I don't have access keys in the OAuth array. </p>\n"
#  '\n'
#  "<p>In POST requests to the API, form data is passed directly into the API call array, but the GET requests are built differently, and I'm not seeing how to pass form data to it. This will work "
#  'fine:</p>\n'
#  '\n'
#  "<pre><code>    $getfield = '?screen_name=TWITTER_SCREEN_NAME';\n"
#  '</code></pre>\n'
#  '\n'
#  "<p>It's when I try $getfield = $_GET['screen_name']; That it goes wrong. Thanks for your time, sorry if this noob stuff is annoying :3</p>\n"]
#  1    9339
# -1    3796
#  0    2755
# Name: label, dtype: int64
#  1    58.772813
# -1    23.889239
#  0    17.337948
# Name: label, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 8))

counts = df.label.value_counts(normalize=True) * 100

sns.barplot(x=counts.index, y=counts, ax=ax)

ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel("Percentage")

plt.show()

# %%
stop_words = stopwords.words('english')
print(stop_words[:20])

tokenizer = RegexpTokenizer(r'\w+')
    
def process_text(headlines):
    tokens = []
    for line in headlines:
        toks = tokenizer.tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        tokens.extend(toks)
    
    return tokens
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his']

# %%
#Positive words from labelled datasets
pos_lines = list(df[df.label == 1].headline)

pos_tokens = process_text(pos_lines)
pos_freq = nltk.FreqDist(pos_tokens)

pos_freq.most_common(20)
# Out:
# [('gt', 217017),
#  ('lt', 193421),
#  ('p', 101776),
#  ('code', 57984),
#  ('1', 43611),
#  ('0', 42401),
#  ('class', 39881),
#  ('com', 39377),
#  ('twitter', 38582),
#  ('div', 37310),
#  ('pre', 30016),
#  ('href', 26521),
#  ('li', 24360),
#  ('api', 22265),
#  ('https', 21820),
#  ('http', 20668),
#  ('2', 20407),
#  ('data', 16662),
#  ('3', 16017),
#  ('id', 15756)]

# %%
#Frequency distribution of positive words, it follows powerlaw distribution
y_val = [x[1] for x in pos_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Positive)")
plt.show()

# %%
#Plot of log which confirms that less words occupied more space
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Positive)")
plt.plot(x_val, y_final)
plt.show()

# %%
#Repeating same steps for negative words
neg_lines = list(df[df.label == -1].headline)

neg_tokens = process_text(neg_lines)
neg_freq = nltk.FreqDist(neg_tokens)

neg_freq.most_common(20)
# Out:
# [('gt', 68594),
#  ('lt', 61512),
#  ('p', 38231),
#  ('code', 23990),
#  ('1', 22547),
#  ('0', 16673),
#  ('com', 16603),
#  ('twitter', 16188),
#  ('pre', 13224),
#  ('org', 11017),
#  ('class', 10500),
#  ('2', 10440),
#  ('api', 10073),
#  ('div', 9104),
#  ('java', 8263),
#  ('https', 7505),
#  ('jar', 7493),
#  ('http', 7368),
#  ('error', 7119),
#  ('href', 6701)]

# %%
y_val = [x[1] for x in neg_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Negative)")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Negative)")
plt.plot(x_val, y_final)
plt.show()
